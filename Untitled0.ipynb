# %% [markdown]
# <a href="https://colab.research.google.com/github/Ripsshu/vest-model/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Feb 28 21:59:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install kagglehub

# %%
import kagglehub

path = kagglehub.dataset_download("adilshamim8/safety-vests-detection-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 406M/406M [00:03<00:00, 128MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1

# %%
import os

for root, dirs, files in os.walk(path):
    print("Folder:", root)
    print("Subfolders:", dirs)
    print("Files:", files[:5])
    print("-" * 50)
    break
# Out:
# Folder: /root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1
# Subfolders: ['train', 'valid', 'test']
# Files: ['README.dataset.txt']
# --------------------------------------------------

# %%
# !ls {path}
# Out:
# README.dataset.txt  test  train  valid

# %%
# !ls {path}/train
# Out:
# train

# %%
# !ls {path}/train/images | head
# Out:
# ls: cannot access '/root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1/train/images': No such file or directory

# %%
# !ls {path}/train/labels | head
# Out:
# ls: cannot access '/root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1/train/labels': No such file or directory

# %%
# !ls {path}/train
# Out:
# train

# %%
# !ls {path}/train | head
# Out:
# train

# %%
# !ls -R {path}/train | head -20
# Out:
# /root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1/train:
# train
#
# /root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1/train/train:
# 000040_jpg.rf.49d5307e76d80bcdb7959efc47947d53.jpg
# 000045_jpg.rf.6df733f2c4076ebe9ab3a25d6ed9b63e.jpg
# 000093_jpg.rf.5a930e33b4dde5d3e0efbeb1f29d1b08.jpg
# 000185_jpg.rf.29cd08286e5a0d6e4c0142a8c5bb5bc5.jpg
# 000190_jpg.rf.26c56a5680e04aa2df6ed993bd8dc26c.jpg
# 00266_jpg.rf.bc4b7941286277d27ed66c163352e538.jpg
# 00270_jpg.rf.38b96ead4f9681856baa78227bf85755.jpg
# 00276_jpg.rf.e6e1653be392a47152f5abef7dcaedeb.jpg
# 00290_jpg.rf.e2c1c9ea9b75942f1c00094b6f357c98.jpg
# 00291_jpg.rf.1da2e7d91f97a6922e43a70d3cb7c7d5.jpg
# 00340_jpg.rf.6eff5fef9b8a6f87f6179c134acb6a38.jpg
# 00341_jpg.rf.266a07c5b867e6c21c1974dafcf05998.jpg
# 00342_jpg.rf.53ef1b61cf23db23c075d27d69132261.jpg
# 00343_jpg.rf.d87162554450de7e210e7963b33adcd1.jpg
# 00354_jpg.rf.fd63906e941f5f1b6f0ebd0cc9c858a1.jpg
# ...

# %%
# !ls {path}/train | grep .txt | head

# %%
# !ls -R {path} | head -50
# Out:
# /root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1:
# README.dataset.txt
# test
# train
# valid
#
# /root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1/test:
# test
#
# /root/.cache/kagglehub/datasets/adilshamim8/safety-vests-detection-dataset/versions/1/test/test:
# 000135_jpg.rf.47b9af3af471cf74399e4d8cc40c94c2.jpg
# 00345_jpg.rf.fb4595dd104aedc4ed137ef0f7e7003c.jpg
# 00372_jpg.rf.800f1e5b4501b9241bada5a25a6466ae.jpg
# 00411_jpg.rf.c7924ce39d548e4788ba2cbd1db9edd6.jpg
# 00446_jpg.rf.7d446dac4306a74ece4fb9050ac75df5.jpg
# 00541_jpg.rf.9d8f7944ab86290fb94cfbc997a79f2f.jpg
# 00542_jpg.rf.9acf2ed87c9a65cc1d0cd008e84d71dd.jpg
# 00588_jpg.rf.1d6a6d0335aa3ca896e1ad9cf37a7bb0.jpg
# 00614_jpg.rf.7700ab3c7bb63c8b2783f86b470614f0.jpg
# 00624_jpg.rf.3ee34347ae51dbe573069eb659bae818.jpg
# 00626_jpg.rf.f4465ac5d66d5d784fbb0b2f935173ec.jpg
# 00627_jpg.rf.a1b9c4088ba48f87059e0046ce59d841.jpg
# ...

# %%
# !rm -rf /root/.cache/kagglehub/datasets/adilshamim8

# %%
# !ls /root/.cache/kagglehub/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KxF09a6NEdYNISVUVxez")
project = rf.workspace("arman-keresh-lbrre").project("vest-no-vest")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 149.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to vest-no-vest-1 in yolov8:: 100%|██████████| 14419/14419 [00:02<00:00, 6387.31it/s]

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/vest-no-vest-1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# ...
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1146.7±457.6 MB/s, size: 51.5 KB)
# val: Scanning /content/vest-no-vest-1/valid/labels.cache... 700 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 700/700 244.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 5.2it/s 8.5s
#                    all        700       1427      0.908      0.898      0.936      0.608
#                no vest        306        562      0.875      0.881      0.903      0.542
#                   vest        468        865      0.941      0.916      0.968      0.675
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63a85c21-093a-4780-96a6-8a19f01d3f04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63a85c21-093a-4780-96a6-8a19f01d3f04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict(source="test.jpg", save=True, conf=0.25)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3124/3508523143.py in <cell line: 0>()
# ----> 1 model.predict(source="test.jpg", save=True, conf=0.25)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
#     224         else:
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a0b288a-3a76-4843-9463-0d234a615e62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a0b288a-3a76-4843-9463-0d234a615e62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict(source="test.jpeg", save=True, conf=0.25)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3124/1542162842.py in <cell line: 0>()
# ----> 1 model.predict(source="test.jpeg", save=True, conf=0.25)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
#     224         else:
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'yolov8n.pt', 'runs', 'test', 'yolo26n.pt', 'vest-no-vest-1', 'test (1)', 'sample_data']

# %%
model.predict(source="test (1)", save=True, conf=0.25)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3124/1020760220.py in <cell line: 0>()
# ----> 1 model.predict(source="test (1)", save=True, conf=0.25)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
#     224         else:
# ...

# %%
import os

# Rename file to test.jpg
os.rename("test (1)", "test.jpg")

# %%
model.predict(source="test.jpg", save=True, conf=0.25)
# Out:
# image 1/1 /content/test.jpg: 448x640 6 vests, 44.1ms
# Speed: 2.1ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'no vest', 1: 'vest'}
#  obb: None
#  orig_img: array([[[237, 229, 222],
#          [237, 229, 222],
#          [237, 229, 222],
#          ...,
#          [218, 213, 210],
#          [218, 213, 210],
#          [218, 213, 210]],
#
#         [[237, 229, 222],
#          [237, 229, 222],
#          [237, 229, 222],
#          ...,
#          [217, 212, 209],
#          [217, 212, 209],
#          [217, 212, 209]],
#
#         [[237, 229, 222],
#          [237, 229, 222],
#          [237, 229, 222],
#          ...,
#          [215, 210, 207],
#          [215, 210, 207],
#          [215, 210, 207]],
#
#         ...,
#
# ...

# %%
from IPython.display import Image
Image("/content/runs/detect/predict/test.jpg")
